# %%
import pandas as pd
import numpy as np 
import warnings
warnings.filterwarnings('ignore')

import pylab as plt
import seaborn as sns

# %matplotlib inline


import matplotlib.pyplot as plt
# %matplotlib inline

# %%
salary= pd.read_csv('data/salaries_data.csv')

# %%
salary.head()
# Out:
#    work_year experience_level employment_type        job_title  salary  \
# 0       2022               SE              FT    Data Engineer  140250
# 1       2022               SE              FT    Data Engineer  135000
# 2       2021               MI              FT  BI Data Analyst  100000
# 3       2021               MI              CT      ML Engineer  270000
# 4       2021               MI              FT    Data Engineer   22000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         140250                 US           100
# 1             USD         135000                 US           100
# 2             USD         100000                 US           100
# 3             USD         270000                 US           100
# 4             EUR          26005                 RO             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# ...

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           500 non-null    int64
#  1   experience_level    500 non-null    object
#  2   employment_type     500 non-null    object
#  3   job_title           500 non-null    object
#  4   salary              500 non-null    int64
#  5   salary_currency     500 non-null    object
#  6   salary_in_usd       500 non-null    int64
#  7   employee_residence  500 non-null    object
#  8   remote_ratio        500 non-null    int64
#  9   company_location    500 non-null    object
#  10  company_size        500 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 43.1+ KB

# %%
salary['work_year'].unique()
# Out:
# array([2022, 2021, 2020])

# %%
salary['work_year'].value_counts()
# Out:
# 2022    263
# 2021    181
# 2020     56
# Name: work_year, dtype: int64

# %%
salary['experience_level'].unique()
# Out:
# array(['SE', 'MI', 'EN', 'EX'], dtype=object)

# %%
salary['employment_type'].unique()
# Out:
# array(['FT', 'CT', 'FL', 'PT'], dtype=object)

# %%
salary['employment_type'].value_counts()
# Out:
# FT    484
# PT      8
# CT      4
# FL      4
# Name: employment_type, dtype: int64

# %%
salary.job_title.value_counts()
# Out:
# Data Scientist                              121
# Data Engineer                               111
# Data Analyst                                 81
# Machine Learning Engineer                    31
# Research Scientist                           12
# Data Science Manager                         12
# Data Architect                                8
# Machine Learning Scientist                    7
# Data Analytics Manager                        7
# Big Data Engineer                             7
# Director of Data Science                      7
# ML Engineer                                   6
# Lead Data Engineer                            6
# Principal Data Scientist                      6
# Applied Data Scientist                        5
# Data Engineering Manager                      5
# Data Science Consultant                       5
# AI Scientist                                  5
# BI Data Analyst                               5
# Head of Data                                  4
# ...

# %%
salary.employee_residence.value_counts()
# Out:
# US    278
# GB     38
# IN     25
# CA     24
# DE     19
# FR     14
# ES     13
# GR     11
# PK      6
# PT      6
# BR      5
# NL      4
# JP      4
# VN      3
# PL      3
# AT      3
# TR      3
# AE      3
# RO      2
# BE      2
# NG      2
# AU      2
# RU      2
# IT      2
# SI      2
# MY      1
# BO      1
# HN      1
# IE      1
# MT      1
# HU      1
# RS      1
# MD      1
# IR      1
# LU      1
# DZ      1
# MX      1
# PR      1
# CZ      1
# EE      1
# HK      1
# BG      1
# UA      1
# NZ      1
# JE      1
# CL      1
# CH      1
# KE      1
# SG      1
# Name: employee_residence, dtype: int64

# %%
salary.remote_ratio.value_counts()
# Out:
# 100    320
# 0      102
# 50      78
# Name: remote_ratio, dtype: int64

# %%
salary.company_location.value_counts()
# Out:
# US    296
# GB     41
# CA     25
# DE     23
# IN     19
# FR     12
# ES     12
# GR     10
# JP      4
# NL      4
# PT      4
# LU      3
# AE      3
# AT      3
# PL      3
# PK      3
# TR      3
# CH      2
# AU      2
# BR      2
# NG      2
# SI      2
# BE      2
# MT      1
# IR      1
# DZ      1
# HU      1
# CZ      1
# HN      1
# RO      1
# CL      1
# EE      1
# UA      1
# NZ      1
# DK      1
# CN      1
# KE      1
# VN      1
# MX      1
# IE      1
# AS      1
# MD      1
# SG      1
# Name: company_location, dtype: int64

# %%
salary.company_size.value_counts()
# Out:
# M    273
# L    165
# S     62
# Name: company_size, dtype: int64

# %%
#Vamos a borrar las columnas salary y salary currency puesto que son dos columnas que incluye ya la columna salary.

# %%
salary= salary.drop(['salary', 'salary_currency'], axis=1)

# %%
salary.head()
# Out:
#    work_year experience_level employment_type        job_title  salary_in_usd  \
# 0       2022               SE              FT    Data Engineer         140250
# 1       2022               SE              FT    Data Engineer         135000
# 2       2021               MI              FT  BI Data Analyst         100000
# 3       2021               MI              CT      ML Engineer         270000
# 4       2021               MI              FT    Data Engineer          26005
#
#   employee_residence  remote_ratio company_location company_size
# 0                 US           100               US            M
# 1                 US           100               US            M
# 2                 US           100               US            M
# 3                 US           100               US            L
# 4                 RO             0               US            L

# %%
salary.describe().T
# Out:
#                count        mean           std     min      25%       50%  \
# work_year      500.0    2021.414      0.683768  2020.0   2021.0    2022.0
# salary_in_usd  500.0  112996.216  69613.750601  2859.0  64594.5  103080.0
# remote_ratio   500.0      71.800     40.472658     0.0     50.0     100.0
#
#                     75%       max
# work_year        2022.0    2022.0
# salary_in_usd  150000.0  450000.0
# remote_ratio      100.0     100.0

# %%
plt.boxplot(salary['salary_in_usd'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f05bb0a29a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f05bb0a2f40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f05bb0a26d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f05bb0bf520>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f05bb0bf7f0>],
#  'means': []}

# %%
#salary.employee=salary.employee_residence.value_counts()

# %%
#salary.employee[:9]

# %%
#salary['employee_residence']= salary['employee_residence'].apply(lambda x: x if x in pais else 'OTHER')

# %%
salary.head()
# Out:
#    work_year experience_level employment_type        job_title  salary_in_usd  \
# 0       2022               SE              FT    Data Engineer         140250
# 1       2022               SE              FT    Data Engineer         135000
# 2       2021               MI              FT  BI Data Analyst         100000
# 3       2021               MI              CT      ML Engineer         270000
# 4       2021               MI              FT    Data Engineer          26005
#
#   employee_residence  remote_ratio company_location company_size
# 0                 US           100               US            M
# 1                 US           100               US            M
# 2                 US           100               US            M
# 3                 US           100               US            L
# 4                 RO             0               US            L

# %%
salary['experience_level'].value_counts()
# Out:
# SE    243
# MI    172
# EN     65
# EX     20
# Name: experience_level, dtype: int64

# %%
#Hemos transformado los datos de la columna exprience_level a números según un jerarquia de experiencia laboral.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()


experience_level = {'EX': 1 , 'SE': 2, 'MI': 3, 'EN': 4}

salary.experience_level=salary.experience_level.apply(lambda x: experience_level[x])

# %%
salary.head()
# Out:
#    work_year  experience_level employment_type        job_title  \
# 0       2022                 2              FT    Data Engineer
# 1       2022                 2              FT    Data Engineer
# 2       2021                 3              FT  BI Data Analyst
# 3       2021                 3              CT      ML Engineer
# 4       2021                 3              FT    Data Engineer
#
#    salary_in_usd employee_residence  remote_ratio company_location  \
# 0         140250                 US           100               US
# 1         135000                 US           100               US
# 2         100000                 US           100               US
# 3         270000                 US           100               US
# 4          26005                 RO             0               US
#
#   company_size
# 0            M
# 1            M
# 2            M
# 3            L
# 4            L

# %%
salary['company_size']= le.fit_transform(salary.company_size)

# %%
salary.head()
# Out:
#    work_year  experience_level employment_type        job_title  \
# 0       2022                 2              FT    Data Engineer
# 1       2022                 2              FT    Data Engineer
# 2       2021                 3              FT  BI Data Analyst
# 3       2021                 3              CT      ML Engineer
# 4       2021                 3              FT    Data Engineer
#
#    salary_in_usd employee_residence  remote_ratio company_location  \
# 0         140250                 US           100               US
# 1         135000                 US           100               US
# 2         100000                 US           100               US
# 3         270000                 US           100               US
# 4          26005                 RO             0               US
#
#    company_size
# 0             1
# 1             1
# 2             1
# 3             0
# 4             0

# %%
#hemos eliminado el tipo de empleo

# %%
salary= salary.drop(columns= 'employment_type', axis=1)

# %%
salary.head()
# Out:
#    work_year  experience_level        job_title  salary_in_usd  \
# 0       2022                 2    Data Engineer         140250
# 1       2022                 2    Data Engineer         135000
# 2       2021                 3  BI Data Analyst         100000
# 3       2021                 3      ML Engineer         270000
# 4       2021                 3    Data Engineer          26005
#
#   employee_residence  remote_ratio company_location  company_size
# 0                 US           100               US             1
# 1                 US           100               US             1
# 2                 US           100               US             1
# 3                 US           100               US             0
# 4                 RO             0               US             0

# %%
salary.remote_ratio.value_counts()
# Out:
# 100    320
# 0      102
# 50      78
# Name: remote_ratio, dtype: int64

# %%
salary.groupby('job_title').mean().sort_values('salary_in_usd', ascending=False)
# Out:
#                                             work_year  experience_level  \
# job_title
# Financial Data Analyst                    2021.000000          3.000000
# Data Analytics Lead                       2022.000000          2.000000
# Principal Data Scientist                  2021.000000          2.000000
# Director of Data Science                  2021.000000          1.142857
# Applied Machine Learning Scientist        2021.333333          3.000000
# Data Architect                            2021.625000          2.375000
# Applied Data Scientist                    2021.600000          2.800000
# Principal Data Analyst                    2021.000000          2.000000
# Head of Data Science                      2021.500000          2.000000
# Data Specialist                           2021.000000          2.000000
# Analytics Engineer                        2022.000000          1.333333
# Data Science Manager                      2021.333333          2.166667
# ...

# %%
job= salary.job_title.value_counts()[:7]

# %%
salary['job_title']= salary['job_title'].apply(lambda x: x if x in job else 'other')

# %%
salary.tail()
# Out:
#      work_year  experience_level       job_title  salary_in_usd  \
# 495       2022                 2   Data Engineer         100000
# 496       2021                 4           other           5882
# 497       2022                 2  Data Architect          90700
# 498       2021                 3   Data Engineer          82528
# 499       2021                 4           other          70000
#
#     employee_residence  remote_ratio company_location  company_size
# 495                 US           100               US             1
# 496                 IN             0               CH             0
# 497                 CA           100               CA             1
# 498                 GB           100               GB             0
# 499                 US           100               US             1

# %%
# Media de salarios para los empleados que residen en la misma localización que la empresa
media_salarios_empresas = salary[salary["employee_residence"] == salary["company_location"]].mean()["salary_in_usd"]

# Media de salarios para los empleados que no residen en la misma localización que la empresa
media_salarios_otros = salary[salary["employee_residence"] != salary["company_location"]].mean()["salary_in_usd"]

# %%
media_salarios_empresas
# Out:
# 115894.93926247288

# %%
media_salarios_otros
# Out:
# 78731.82051282052

# %%
test= pd.read_csv('data/testeo.csv')

# %%
len(salary.employee_residence.value_counts())
# Out:
# 49

# %%
len(test.employee_residence.value_counts())
# Out:
# 26

# %%
#Aqui vemos que los que viven en la misma ciudad que la localizacion de la empresa, cobran más que los que viven fuera de dicha localización, por tanto afecta al salario vivir fuera o no.

#Por lo que me resulta, más importante la columna de employee_residence, ya que afecta al salario más que company_location, vamos a eliminar esta columna por redundanica.

# %%
salary= salary.drop(columns= 'company_location', axis=1)

# %%
salary.head()
# Out:
#    work_year  experience_level      job_title  salary_in_usd  \
# 0       2022                 2  Data Engineer         140250
# 1       2022                 2  Data Engineer         135000
# 2       2021                 3          other         100000
# 3       2021                 3          other         270000
# 4       2021                 3  Data Engineer          26005
#
#   employee_residence  remote_ratio  company_size
# 0                 US           100             1
# 1                 US           100             1
# 2                 US           100             1
# 3                 US           100             0
# 4                 RO             0             0

# %%
residence= salary.employee_residence.value_counts()[:8]

# %%
salary['employee_residence'].value_counts()
# Out:
# US    278
# GB     38
# IN     25
# CA     24
# DE     19
# FR     14
# ES     13
# GR     11
# PK      6
# PT      6
# BR      5
# NL      4
# JP      4
# VN      3
# PL      3
# AT      3
# TR      3
# AE      3
# RO      2
# BE      2
# NG      2
# AU      2
# RU      2
# IT      2
# SI      2
# MY      1
# BO      1
# HN      1
# IE      1
# MT      1
# HU      1
# RS      1
# MD      1
# IR      1
# LU      1
# DZ      1
# MX      1
# PR      1
# CZ      1
# EE      1
# HK      1
# BG      1
# UA      1
# NZ      1
# JE      1
# CL      1
# CH      1
# KE      1
# SG      1
# Name: employee_residence, dtype: int64

# %%
salary['employee_residence']= salary['employee_residence'].apply(lambda x: x if x in residence else 'other')

# %%
salary.head()
# Out:
#    work_year  experience_level      job_title  salary_in_usd  \
# 0       2022                 2  Data Engineer         140250
# 1       2022                 2  Data Engineer         135000
# 2       2021                 3          other         100000
# 3       2021                 3          other         270000
# 4       2021                 3  Data Engineer          26005
#
#   employee_residence  remote_ratio  company_size
# 0                 US           100             1
# 1                 US           100             1
# 2                 US           100             1
# 3                 US           100             0
# 4              other             0             0

# %%
salary.groupby('remote_ratio').mean().sort_values('salary_in_usd', ascending=False)
# Out:
#                 work_year  experience_level  salary_in_usd  company_size
# remote_ratio
# 100           2021.518750          2.490625  122960.275000      0.856250
# 0             2021.480392          2.617647  103952.176471      0.803922
# 50            2020.897436          2.794872   83944.846154      0.525641

# %%
remote_ratio = {100: 1 , 0: 2, 50: 3}

salary.remote_ratio=salary.remote_ratio.apply(lambda x: remote_ratio[x])

# %%
salary.head()
# Out:
#    work_year  experience_level      job_title  salary_in_usd  \
# 0       2022                 2  Data Engineer         140250
# 1       2022                 2  Data Engineer         135000
# 2       2021                 3          other         100000
# 3       2021                 3          other         270000
# 4       2021                 3  Data Engineer          26005
#
#   employee_residence  remote_ratio  company_size
# 0                 US             1             1
# 1                 US             1             1
# 2                 US             1             1
# 3                 US             1             0
# 4              other             2             0

# %%
salaryy= pd.get_dummies(salary, columns=['job_title','employee_residence'], drop_first=True)

salaryy.head()
# Out:
#    work_year  experience_level  salary_in_usd  remote_ratio  company_size  \
# 0       2022                 2         140250             1             1
# 1       2022                 2         135000             1             1
# 2       2021                 3         100000             1             1
# 3       2021                 3         270000             1             0
# 4       2021                 3          26005             2             0
#
#    job_title_Data Architect  job_title_Data Engineer  \
# 0                         0                        1
# 1                         0                        1
# 2                         0                        0
# 3                         0                        0
# 4                         0                        1
#
#    job_title_Data Science Manager  job_title_Data Scientist  \
# 0                               0                         0
# 1                               0                         0
# ...

# %%
X = salaryy.drop('salary_in_usd', axis=1)

y = salaryy.salary_in_usd

# %%
X.shape, y.shape
# Out:
# ((500, 19), (500,))

# %%
from sklearn.model_selection import train_test_split as tts  # el alias es cosa mia

X_train, X_test, y_train, y_test  = tts(X, y, train_size=0.8, test_size=0.2, random_state=42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((400, 19), (100, 19), (400,), (100,))

# %%
from sklearn.linear_model import LinearRegression as LinReg   # alias es mio

from sklearn.linear_model import Lasso        # regularizacion L1
from sklearn.linear_model import Ridge        # regularizacion L2
from sklearn.linear_model import ElasticNet   # regularizacion L1+L2


# se inician los modelos

linreg=LinReg()
lasso=Lasso()
ridge=Ridge()
elastic=ElasticNet()
from sklearn.svm import SVR  # support vector regressor

svr=SVR()

# %%
from sklearn.ensemble import RandomForestRegressor as RFR  

from sklearn.tree import ExtraTreeRegressor as ETR

rfr=RFR()

etr=ETR()

# %%
from sklearn.ensemble import GradientBoostingRegressor as GBR

from xgboost import XGBRegressor as XGBR

from catboost import CatBoostRegressor as CTR

from lightgbm import LGBMRegressor as LGBMR


gbr=GBR()
xgbr=XGBR()
ctr=CTR()
lgbmr=LGBMR()

# %%
# %pip install lazypredict
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from lazypredict.Supervised import LazyRegressor 

lazy=LazyRegressor()

lazy.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|███████████████████████████████████████████| 42/42 [00:06<00:00,  6.86it/s]
# (                               Adjusted R-Squared  R-Squared      RMSE  \
#  Model
#  ElasticNet                                   0.26       0.40  48325.21
#  HuberRegressor                               0.25       0.40  48616.49
#  PassiveAggressiveRegressor                   0.25       0.39  48720.76
#  TweedieRegressor                             0.23       0.38  49222.45
#  GammaRegressor                               0.23       0.38  49222.84
#  BayesianRidge                                0.23       0.38  49422.56
#  RidgeCV                                      0.22       0.37  49681.69
#  LassoLarsCV                                  0.21       0.36  49891.98
#  LarsCV                                       0.21       0.36  49891.98
#  LassoCV                                      0.21       0.36  49939.69
#  SGDRegressor                                 0.21       0.36  50087.57
# ...

# %%
test= pd.read_csv('data/testeo.csv')

# %%
test.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               SE              FT  Machine Learning Scientist
# 1       2020               MI              FT           Lead Data Analyst
# 2       2020               MI              FT                Data Analyst
# 3       2020               MI              FT   Machine Learning Engineer
# 4       2020               MI              FT        Product Data Analyst
#
#   employee_residence  remote_ratio company_location company_size
# 0                 JP             0               JP            S
# 1                 US           100               US            L
# 2                 US           100               US            L
# 3                 CN             0               CN            M
# 4                 IN           100               IN            L

# %%
test= test.drop(columns = ['company_location', 'employment_type', 'company_location'])

# %%
test.head()
# Out:
#    work_year experience_level                   job_title employee_residence  \
# 0       2020               SE  Machine Learning Scientist                 JP
# 1       2020               MI           Lead Data Analyst                 US
# 2       2020               MI                Data Analyst                 US
# 3       2020               MI   Machine Learning Engineer                 CN
# 4       2020               MI        Product Data Analyst                 IN
#
#    remote_ratio company_size
# 0             0            S
# 1           100            L
# 2           100            L
# 3             0            M
# 4           100            L

# %%
experience_level = {'EX': 1 , 'SE': 2, 'MI': 3, 'EN': 4}

test.experience_level=test.experience_level.apply(lambda x: experience_level[x])

# %%
residence= test.employee_residence.value_counts()[:8]

# %%
test['employee_residence']= test['employee_residence'].apply(lambda x: x if x in residence else 'other')

# %%
job= test.job_title.value_counts()[:7]

test['job_title']= test['job_title'].apply(lambda x: x if x in job else 'other')

# %%
test.job_title.value_counts()
# Out:
# other                        28
# Data Scientist               22
# Data Engineer                21
# Data Analyst                 16
# Machine Learning Engineer    10
# Research Scientist            4
# Principal Data Engineer       3
# Data Architect                3
# Name: job_title, dtype: int64

# %%
salary.job_title.value_counts()
# Out:
# other                        124
# Data Scientist               121
# Data Engineer                111
# Data Analyst                  81
# Machine Learning Engineer     31
# Research Scientist            12
# Data Science Manager          12
# Data Architect                 8
# Name: job_title, dtype: int64

# %%
remote_ratio = {100: 1 , 0: 2, 50: 3}

test.remote_ratio=test.remote_ratio.apply(lambda x: remote_ratio[x])

# %%
test['company_size']= le.fit_transform(test.company_size)

# %%
test.head()
# Out:
#    work_year  experience_level                  job_title employee_residence  \
# 0       2020                 2                      other                 JP
# 1       2020                 3                      other                 US
# 2       2020                 3               Data Analyst                 US
# 3       2020                 3  Machine Learning Engineer              other
# 4       2020                 3                      other                 IN
#
#    remote_ratio  company_size
# 0             2             2
# 1             1             0
# 2             1             0
# 3             2             1
# 4             1             0

# %%
testt= pd.get_dummies(test, columns=['job_title','employee_residence'], drop_first=True)

testt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   work_year                            107 non-null    int64
#  1   experience_level                     107 non-null    int64
#  2   remote_ratio                         107 non-null    int64
#  3   company_size                         107 non-null    int64
#  4   job_title_Data Architect             107 non-null    uint8
#  5   job_title_Data Engineer              107 non-null    uint8
#  6   job_title_Data Scientist             107 non-null    uint8
#  7   job_title_Machine Learning Engineer  107 non-null    uint8
#  8   job_title_Principal Data Engineer    107 non-null    uint8
#  9   job_title_Research Scientist         107 non-null    uint8
#  10  job_title_other                      107 non-null    uint8
# ...

# %%
salaryy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   work_year                            500 non-null    int64
#  1   experience_level                     500 non-null    int64
#  2   salary_in_usd                        500 non-null    int64
#  3   remote_ratio                         500 non-null    int64
#  4   company_size                         500 non-null    int64
#  5   job_title_Data Architect             500 non-null    uint8
#  6   job_title_Data Engineer              500 non-null    uint8
#  7   job_title_Data Science Manager       500 non-null    uint8
#  8   job_title_Data Scientist             500 non-null    uint8
#  9   job_title_Machine Learning Engineer  500 non-null    uint8
#  10  job_title_Research Scientist         500 non-null    uint8
# ...

# %%
salary['employee_residence'].unique()
# Out:
# array(['US', 'other', 'FR', 'GR', 'DE', 'IN', 'GB', 'CA', 'ES'],
#       dtype=object)

# %%
test['employee_residence'].unique()
# Out:
# array(['JP', 'US', 'other', 'IN', 'FR', 'DE', 'GB', 'CA', 'RU'],
#       dtype=object)

# %%
X.shape, y.shape
# Out:
# ((500, 19), (500,))

# %%
from sklearn.linear_model import ElasticNet

en = ElasticNet()

en.fit(X, y)
# Out:
# ElasticNet()

# %%
testt.shape
# Out:
# (107, 19)

# %%
y_pred = en.predict(testt)

# %%
y_pred
# Out:
# array([100349.1587313 , 125621.18063783, 121102.62187896,  78306.79409166,
#        101809.83672192,  88293.34486086, 111442.65297371,  85135.55798184,
#         77978.31197286, 138818.26212747,  50180.29913271, 129185.68192116,
#         82797.51372653,  47003.96984514,  95919.3810044 ,  71871.0328016 ,
#        124538.27161848, 127693.01352205,  72216.34426831,  91073.93061762,
#         85716.47301778,  88160.20274956, 102132.28077173, 135812.55780492,
#         66324.48199995,  52252.13201692,  84993.96534442, 140492.22198215,
#         87353.52218285, 126883.13849594, 125638.13905937, 103174.92231307,
#        126951.12345042,  73412.18077167,  55462.66273736,  83084.22287742,
#        139247.22254559,  73991.76696787,  63310.11921034, 143115.93513069,
#         52252.13201692,  85024.08325683, 123174.45476317, 143374.27058379,
#         91052.34323362, 161973.52148   , 108670.7534474 ,  61742.460956  ,
# ...

# %%
muestra= pd.read_csv('data/muestra.csv')

# %%
# csv muestra


muestra['salary_in_usd'] = y_pred

# Exportar muestra y subir a Kaggle

# %%
muestra.to_csv('muestra1.csv', index=False)
